# %% [markdown]
# <a href="https://colab.research.google.com/github/SmirnovKol/recurrent-visual-attention/blob/master/train_and_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.chdir('/content/drive/MyDrive/contests/20211122_implement_papers_using_paddlepaddle/paper10-recurrent-visual-attention-master')

# %%
# !pwd
# Out:
# /content/drive/MyDrive/contests/20211122_implement_papers_using_paddlepaddle/paper10-recurrent-visual-attention-master

# %%
# !pip install tensorboard_logger

# %%
# !python main.py
# Out:
# [*] Model Checkpoint Dir: ./ckpt
# [*] Param Path: ./ckpt/ram_6_8x8_1_params.json
#
# [*] Train on 54000 samples, validate on 6000 samples
#
# Epoch: 1/200 - LR: 0.000300
# 50.5s - loss: 1.230 - acc: 65.179: 100% 54000/54000 [00:50<00:00, 1067.89it/s]
# train loss: 1.479 - train acc: 57.722 - val loss: 1.022 - val acc: 72.483 - val err: 27.517 [*]
#
# Epoch: 2/200 - LR: 0.000300
# 50.9s - loss: 0.695 - acc: 81.250: 100% 54000/54000 [00:50<00:00, 1061.11it/s]
# train loss: 0.837 - train acc: 78.102 - val loss: 0.718 - val acc: 81.717 - val err: 18.283 [*]
#
# Epoch: 3/200 - LR: 0.000300
# 50.6s - loss: 0.470 - acc: 89.286: 100% 54000/54000 [00:50<00:00, 1066.67it/s]
# train loss: 0.630 - train acc: 84.176 - val loss: 0.553 - val acc: 86.150 - val err: 13.850 [*]
#
# Epoch: 4/200 - LR: 0.000300
# 50.5s - loss: 0.424 - acc: 87.500: 100% 54000/54000 [00:50<00:00, 1068.70it/s]
# train loss: 0.486 - train acc: 88.024 - val loss: 0.446 - val acc: 88.917 - val err: 11.083 [*]
#
# ...

# %%
# !python ./main.py --is_train=False
# Out:
# [*] Loading model from ./ckpt
# [*] Loaded ram_6_8x8_1_model_best.pth.tar checkpoint @ epoch 177 with best valid acc of 98.900
# [*] Test Acc: 9872/10000 (98.72% - 1.28%)

# %%
# !python ./main.py --is_train=False
# Out:
# ...
# 9913344it [00:00, 49449636.37it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# ...
# 29696it [00:00, 53710242.17it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# ...
# 1649664it [00:00, 27387123.04it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# ...
# 5120it [00:00, 26414313.01it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# [*] Loading model from ./ckpt
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/contests/20211122_implement_papers_using_paddlepaddle/paper10-recurrent-visual-attention-master/main.py", line 49, in <module>
#     main(config)
#   File "/content/drive/MyDrive/contests/20211122_implement_papers_using_paddlepaddle/paper10-recurrent-visual-attention-master/main.py", line 44, in main
#     trainer.test()
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py", line 28, in decorate_context
# ...
